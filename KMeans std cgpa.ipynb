# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.read_csv(r"C:\Users\Hp\Downloads\std_cgpa.txt")
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
df = pd.read_csv(r"C:\Users\Hp\Downloads\std_cgpa.txt")

# %%
df
# Out:
#      cgpa   iq
# 0    5.13   88
# 1    5.90  113
# 2    8.36   93
# 3    8.27   97
# 4    5.45  110
# ..    ...  ...
# 195  4.68   89
# 196  8.57  118
# 197  5.85  112
# 198  6.23  108
# 199  8.82  117
#
# [200 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# cgpa    0
# iq      0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# cgpa    float64
# iq        int64
# dtype: object

# %%
plt.scatter(df["cgpa"],df["iq"])

# %%
from sklearn.cluster import KMeans

# %%
KMeans(n_clusters=4)
# Out:
# KMeans(n_clusters=4)

# %%
km = KMeans(n_clusters=4)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
km.fit_predict(df)
# Out:
# array([3, 2, 1, 1, 2, 2, 1, 0, 2, 1, 3, 2, 1, 3, 2, 1, 2, 1, 2, 2, 1, 3,
#        1, 3, 3, 1, 3, 0, 1, 2, 0, 2, 0, 2, 1, 1, 0, 2, 3, 2, 3, 1, 1, 3,
#        0, 0, 1, 2, 0, 2, 3, 3, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 1, 0, 3, 0,
#        1, 3, 2, 1, 2, 0, 1, 3, 2, 0, 2, 0, 3, 1, 1, 0, 2, 3, 0, 3, 0, 2,
#        0, 2, 0, 0, 1, 3, 1, 1, 0, 1, 3, 0, 2, 3, 3, 0, 3, 3, 1, 3, 0, 0,
#        1, 0, 2, 2, 1, 0, 1, 2, 0, 3, 3, 2, 1, 0, 1, 3, 1, 2, 3, 1, 1, 2,
#        3, 3, 2, 0, 2, 3, 1, 1, 1, 3, 2, 3, 3, 0, 3, 0, 2, 3, 0, 3, 0, 0,
#        3, 1, 2, 0, 2, 1, 3, 0, 2, 1, 0, 3, 2, 3, 3, 0, 0, 2, 0, 3, 3, 1,
#        0, 2, 3, 0, 0, 2, 2, 2, 1, 3, 1, 1, 0, 2, 1, 1, 3, 3, 1, 3, 0, 2,
#        2, 0])

# %%
km.cluster_centers_
# Out:
# array([[  8.8714, 117.16  ],
#        [  8.1998,  94.6   ],
#        [  5.8948, 109.52  ],
#        [  4.9676,  86.7   ]])

# %%
km.inertia_
# Out:
# 681.96966

# %%
y_pred = km.fit_predict(df)

# %%
y_pred
# Out:
# array([2, 3, 1, 1, 3, 3, 1, 0, 3, 1, 2, 3, 1, 2, 3, 1, 3, 1, 3, 3, 1, 2,
#        1, 2, 2, 1, 2, 0, 1, 3, 0, 3, 0, 3, 1, 1, 0, 3, 2, 3, 2, 1, 1, 2,
#        0, 0, 1, 3, 0, 3, 2, 2, 0, 1, 0, 3, 3, 0, 3, 0, 3, 1, 1, 0, 2, 0,
#        1, 2, 3, 1, 3, 0, 1, 2, 3, 0, 3, 0, 2, 1, 1, 0, 3, 2, 0, 2, 0, 3,
#        0, 3, 0, 0, 1, 2, 1, 1, 0, 1, 2, 0, 3, 2, 2, 0, 2, 2, 1, 2, 0, 0,
#        1, 0, 3, 3, 1, 0, 1, 3, 0, 2, 2, 3, 1, 0, 1, 2, 1, 3, 2, 1, 1, 3,
#        2, 2, 3, 0, 3, 2, 1, 1, 1, 2, 3, 2, 2, 0, 2, 0, 3, 2, 0, 2, 0, 0,
#        2, 1, 3, 0, 3, 1, 2, 0, 3, 1, 0, 2, 3, 2, 2, 0, 0, 3, 0, 2, 2, 1,
#        0, 3, 2, 0, 0, 3, 3, 3, 1, 2, 1, 1, 0, 3, 1, 1, 2, 2, 1, 2, 0, 3,
#        3, 0])

# %%
df["cluster"] = y_pred

# %%
df
# Out:
#      cgpa   iq  cluster
# 0    5.13   88        2
# 1    5.90  113        3
# 2    8.36   93        1
# 3    8.27   97        1
# 4    5.45  110        3
# ..    ...  ...      ...
# 195  4.68   89        2
# 196  8.57  118        0
# 197  5.85  112        3
# 198  6.23  108        3
# 199  8.82  117        0
#
# [200 rows x 3 columns]

# %%
df[df["cluster"]== 0]
# Out:
#      cgpa   iq  cluster
# 7    8.80  115        0
# 27   9.18  119        0
# 30   8.86  117        0
# 32   8.83  118        0
# 36   8.56  118        0
# 44   8.96  116        0
# 45   8.78  116        0
# 48   8.45  119        0
# 52   8.79  116        0
# 54   8.81  115        0
# 57   8.88  115        0
# 59   9.07  117        0
# 63   8.92  118        0
# 65   8.75  113        0
# 71   8.71  116        0
# 75   8.86  118        0
# 77   9.30  117        0
# 81   9.01  121        0
# 84   8.97  116        0
# 86   9.00  117        0
# 88   8.76  117        0
# 90   8.78  117        0
# 91   9.23  114        0
# 96   9.03  118        0
# 99   9.13  118        0
# 103  8.91  119        0
# 108  8.98  118        0
# 109  9.03  118        0
# 111  8.86  117        0
# 115  8.89  118        0
# 118  8.97  117        0
# 123  8.72  119        0
# 135  8.93  118        0
# 145  8.58  118        0
# 147  8.94  117        0
# 150  8.60  117        0
# 152  8.77  117        0
# ...

# %%
df_zero = df[df["cluster"]== 0]

# %%
df_zero
# Out:
#      cgpa   iq  cluster
# 7    8.80  115        0
# 27   9.18  119        0
# 30   8.86  117        0
# 56   5.85  111        3
# 58   5.87  109        3
# 60   6.02  104        3
# 68   5.77  111        3
# 70   6.06  109        3
# 74   5.55  109        3
# 76   5.81  112        3
# 82   5.47  111        3
# 87   5.74  109        3
# 89   5.80  108        3
# 100  5.88  110        3
# 112  5.91  109        3
# 113  5.67  111        3
# 117  5.74  108        3
# 121  5.69  109        3
# 127  6.05  109        3
# 131  6.14  111        3
# 134  5.74  112        3
# 136  5.94  109        3
# 142  5.86  111        3
# ...

# %%
df.head()
# Out:
#    cgpa   iq  cluster
# 0  5.13   88        2
# 1  5.90  113        3
# 2  8.36   93        1
# 3  8.27   97        1
# 4  5.45  110        3

# %%
plt.scatter(df_zero["cgpa"],df_zero["iq"],color="r",marker="*")

# %%
plt.scatter(df_one["cgpa"],df_one["iq"],color="b",marker="*")

# %%
plt.scatter(df_two["cgpa"],df_two["iq"],color="m",marker="*")

# %%
plt.scatter(df_three["cgpa"],df_three["iq"],color="y",marker="*")

# %%
plt.scatter(df_zero["cgpa"],df_zero["iq"],color="r",marker="*")
plt.scatter(df_one["cgpa"],df_one["iq"],color="b",marker="*")
plt.scatter(df_two["cgpa"],df_two["iq"],color="m",marker="*")
plt.scatter(df_three["cgpa"],df_three["iq"],color="y",marker="*")

# %%
plt.scatter(df_zero["cgpa"],df_zero["iq"],marker="^",color="r")
plt.scatter(df_one["cgpa"],df_one["iq"],marker="s",color="b")
plt.scatter(df_two["cgpa"],df_two["iq"],marker="*",color="c")
plt.scatter(df_three["cgpa"],df_three["iq"],marker="o",color="y")
plt.show()

# %%
clust = km.cluster_centers_

# %%
pd.DataFrame(clust,columns=["x","y"])
# Out:
#         x       y
# 0  8.8714  117.16
# 1  8.1998   94.60
# 2  4.9676   86.70
# 3  5.8948  109.52

# %%
df_ct = pd.DataFrame(clust,columns=["x","y"])

# %%
df_ct
# Out:
#         x       y
# 0  8.8714  117.16
# 1  8.1998   94.60
# 2  4.9676   86.70
# 3  5.8948  109.52

# %%
plt.scatter(df_ct["x"],df_ct["y"],marker = "|",s=300,color="k")

# %%
plt.scatter(df_zero["cgpa"],df_zero["iq"],color="r",marker="*")
plt.scatter(df_ct["x"],df_ct["y"],marker = "|",s=300,color="k")

# %%
plt.scatter(df_zero["cgpa"],df_zero["iq"],marker="^",color="r")
plt.scatter(df_one["cgpa"],df_one["iq"],marker="s",color="b")
plt.scatter(df_two["cgpa"],df_two["iq"],marker="*",color="c")
plt.scatter(df_three["cgpa"],df_three["iq"],marker="o",color="y")
plt.scatter(df_ct["x"],df_ct["y"],marker = "|",s=300,color="k")
plt.show()

# %%
for i in range(1,11):
    km1 = KMeans(n_clusters=i)
    km1.fit_predict(df)
    print(km1.inertia_)
# Out:
# 30207.898288
# 4434.14127
# 2528.397581
# 681.96966
# 515.12321877865
# 405.7833563948116
# 309.0632469364393
# 233.54082485509016
# 204.33441047547043
# 177.49471957076548

# %%
km1
# Out:
# KMeans(n_clusters=10)

# %%
wcss_list = []
for i in range(1,11):
    km1 = KMeans(n_clusters=i)
    km1.fit_predict(df)
    wcss_list.append(km1.inertia_)

# %%
print(wcss_list)
# Out:
# [30207.898288, 4434.14127, 2528.397581, 681.96966, 515.12321877865, 396.22368872736786, 318.5809621767881, 241.70118319588107, 199.17038501369152, 171.40590752168498]

# %%
plt.plot(range(1,11),wcss_list)
